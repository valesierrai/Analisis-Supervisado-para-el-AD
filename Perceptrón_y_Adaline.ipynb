# %% [markdown]
# <a href="https://colab.research.google.com/github/valesierrai/Analisis-Supervisado-para-el-AD/blob/main/Perceptro%CC%81n_y_Adaline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Perceptrón

# %% [markdown]
# El perceptrón es uno de los modelos más simples de redes neuronales. Es un clasificador binario que toma una decisión lineal para separar dos clases. Utiliza una función de activación escalón para determinar la salida. Debería ofrecer una precisión alta si los datos son linealmente separables.
#
# En este caso, podemos usar datos simples como la clasificación de transacciones contables en "gastos" (0) e e"ingresos" (1).
#
# | Montos | Tipo |
# |--------|------|
# | 500    | 1    | (Ingreso)
# | 300    | 1    | (Ingreso)
# | -200   | 0    | (Gasto)
# | -150   | 0    | (Gasto)

# %% [markdown]
# ## Implementación en `tensorflow`

# %%
import tensorflow as tf
import numpy as np

# Datos del ejemplo, creamos los datos de entrada (montos) y la etiqueta (tipos)
montos = np.array([[500], [300], [-200], [-150]], dtype=np.float32)
tipos = np.array([[1], [1], [0], [0]], dtype=np.float32)

# Creamos el modelo de perceptrón. units el número de neuronas. El perceptrón tiene 1
# La función de activación debería ser escalón, pero keras no la tiene...usaremos la más similar
modelo = tf.keras.Sequential([tf.keras.layers.Dense(units=1, activation = 'sigmoid')])

# Compilamos el modelo. El optimizador será el que se encargue de actualizar
# los pesos, en este caso será gradiente descendente estocástico
modelo.compile(optimizer = 'sgd', loss = 'binary_crossentropy',
               metrics = ['accuracy'])

# Entrenamos el modelo modelo.
# Una época significa entrenar la red neuronal con todos los datos
# de entrenamiento para un ciclo . En una época, usamos todos los datos exactamente una vez.
# Un pase hacia adelante para el cálculo de la salida y un pase hacia atrás para el cálculo del error,
# juntos se cuentan como un pase.
# Una época se compone de uno o más lotes, donde usamos una parte del conjunto de datos para
# entrenar la red neuronal.
modelo.fit(montos, tipos, epochs=10)

# Calculamos la precisión (accuracy)
predicted = modelo.predict(montos)
predicted_classes = (predicted >= 0.5).astype(int)
accuracy = np.mean(predicted_classes.flatten() == tipos.flatten())
print(accuracy)

# Evaluamos el modelo con el error de entrenamiento
predicted = modelo.predict(montos)
predicted_classes = (predicted >= 0.5).astype(int)  # Umbral para clasificación (0.5))
print(predicted_classes)
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step - accuracy: 0.0000e+00 - loss: 217.8757
# Epoch 2/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 3/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 4/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 5/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 6/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 7/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 8/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 9/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# Epoch 10/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 1.0000 - loss: 0.0000e+00
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1.0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# [[1]
#  [1]
#  [0]
#  [0]]

# %% [markdown]
# ## Implementación en `Pytorch`

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# hacemos tensores con los datos de entrada y la variable objetivo
X = torch.tensor(montos, dtype=torch.float32)

y = torch.tensor(tipos, dtype=torch.float32)

# Hacemos la clase perceptrón. En el __init__ están los atributos de la clase
# las demás funciones son llamados métodos
class Perceptron(nn.Module):
    def __init__(self):
        super(Perceptron, self).__init__()
        self.linear = nn.Linear(1, 1) #define las entradas y las neuronas en cada capa.
                                      #tenemos solo una caracterítica a la entrada

    def forward(self, x): #es el método para aplicar un sigmoide a la salida. La idea sería un escalón
        return torch.sigmoid(self.linear(x))

# Definimos un objeto de la clase Perceptrón
model_pytorch = Perceptron()

# Establecemos el criterio de pérdida (Binary Cross Entropy Loss) y
# el optimizador (gradiente descendente)
criterion = nn.BCELoss()
optimizer = optim.SGD(model_pytorch.parameters(), lr=0.01) #lr es la tasa de aprendizaje

# Hacemos el entrenamiento con 100 épocas
for epoch in range(100):
    optimizer.zero_grad() # limpiar los gradientes anteriores
    outputs = model_pytorch(X) #entrenamos
    loss = criterion(outputs, y) #calculamos la pérdida
    loss.backward() #hacemos el backward para calcular los nuevos gradientes
    optimizer.step() #ajustamos los pesos del modelo usando los gradientes calculados en loss.backward()

# Evaluamos la red con el mismo conjunto de entrenamiento (acierto de entrenamiento = 1- error de entrenamiento)
with torch.no_grad():
    predicted = model_pytorch(X) #realizamos la predicción
    predicted_classes = (predicted >= 0.5).float() #establecemos el umbral
    accuracy = (predicted_classes.eq(y).sum().item()) / y.size(0) #calculamos el acierto
    print(f'Perceptrón (PyTorch) - Precisión: {accuracy*100:.2f}%')
# Out:
# Perceptrón (PyTorch) - Precisión: 100.00%

# %% [markdown]
# # Adaline  (ADAptive LInear NEuron)

# %% [markdown]
# Adaline es similar al perceptrón, pero en lugar de usar una función de activación escalón, utiliza una función de activación lineal y minimiza el error cuadrático medio. Esto lo hace más adecuado para problemas de regresión y clasificación con gradiente descendente.
#
# Vamos a crear un conjunto de datos relacionado con la aprobación de préstamos. Las características serán:
#
# - Ingresos mensuales (en miles de dólares)
# - Deuda actual (en miles de dólares)
# - Historial de crédito (1: bueno, 0: malo)
#
# |Ingresos|	Deuda	|Historial	|Aprobado|
# |--------|--------|-----------|--------|
# |5	|1.5	|1|	1|
# |3	|2.0	|0	|0|
# |4	|1.0	|1	|1|
# |2	|2.5	|0	|0|
# |6	|1.2	|1	|1|
# |3.5|	2.2	|0	|0|

# %%
# Cargamos las librería
import tensorflow as tf
import numpy as np

# Definimos la matriz de datos o características
X = np.array([
    [5, 1.5, 1],
    [3, 2.0, 0],
    [4, 1.0, 1],
    [2, 2.5, 0],
    [6, 1.2, 1],
    [3.5, 2.2, 0]
], dtype=float)

# Nuestra característica objetivo será la columna Aprobado
y = np.array([1, 0, 1, 0, 1, 0], dtype=float)

# %% [markdown]
# ## Implementación con `tensorflow`

# %%
# Instanciamos el modelo Adaline. Aunque no existe directamente, se puede generar con la función de activación lineal.
# Tenemos tres entradas (Ingreso, Deuda, Historial)
model_adaline = tf.keras.Sequential([tf.keras.layers.Dense(1, activation='linear', input_shape=(3,))])

# Compilamos nuestro modelo. Para Adaline la función de pérdida está dada por el MSE
model_adaline.compile(optimizer='sgd',
                      loss='mean_squared_error',
                      metrics=['mean_squared_error'])

# Entrenamos el modelo. Al establecer el parámetro 'verbose' en  0, 1 o 2, simplemente dices cómo deseas "ver" el progreso del entrenamiento para cada época.
model_adaline.fit(X, y, epochs=200, verbose=1)

# Evaluamos el modelo con el error de entrenamiento
mse = model_adaline.evaluate(X, y, verbose=0)
print(f'Adaline - MSE: {mse[1]:.4f}')
# Out:
# Epoch 1/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - loss: 0.4638 - mean_squared_error: 0.4638
# Epoch 2/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.4433 - mean_squared_error: 0.4433
# Epoch 3/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.4266 - mean_squared_error: 0.4266
# Epoch 4/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.4115 - mean_squared_error: 0.4115
# Epoch 5/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3975 - mean_squared_error: 0.3975
# Epoch 6/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.3841 - mean_squared_error: 0.3841
# Epoch 7/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.3713 - mean_squared_error: 0.3713
# Epoch 8/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3591 - mean_squared_error: 0.3591
# Epoch 9/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.3474 - mean_squared_error: 0.3474
# Epoch 10/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.3362 - mean_squared_error: 0.3362
# Epoch 11/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.3254 - mean_squared_error: 0.3254
# Epoch 12/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3151 - mean_squared_error: 0.3151
# Epoch 13/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.3052 - mean_squared_error: 0.3052
# Epoch 14/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2958 - mean_squared_error: 0.2958
# Epoch 15/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.2867 - mean_squared_error: 0.2867
# Epoch 16/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.2780 - mean_squared_error: 0.2780
# Epoch 17/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.2696 - mean_squared_error: 0.2696
# Epoch 18/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.2616 - mean_squared_error: 0.2616
# Epoch 19/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2539 - mean_squared_error: 0.2539
# Epoch 20/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.2466 - mean_squared_error: 0.2466
# Epoch 21/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.2395 - mean_squared_error: 0.2395
# Epoch 22/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.2328 - mean_squared_error: 0.2328
# Epoch 23/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.2263 - mean_squared_error: 0.2263
# Epoch 24/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2200 - mean_squared_error: 0.2200
# Epoch 25/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.2141 - mean_squared_error: 0.2141
# Epoch 26/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.2084 - mean_squared_error: 0.2084
# Epoch 27/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.2029 - mean_squared_error: 0.2029
# Epoch 28/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1976 - mean_squared_error: 0.1976
# Epoch 29/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1926 - mean_squared_error: 0.1926
# Epoch 30/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1877 - mean_squared_error: 0.1877
# Epoch 31/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1831 - mean_squared_error: 0.1831
# Epoch 32/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1786 - mean_squared_error: 0.1786
# Epoch 33/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1744 - mean_squared_error: 0.1744
# Epoch 34/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.1703 - mean_squared_error: 0.1703
# Epoch 35/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1663 - mean_squared_error: 0.1663
# Epoch 36/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1626 - mean_squared_error: 0.1626
# Epoch 37/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.1589 - mean_squared_error: 0.1589
# Epoch 38/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.1555 - mean_squared_error: 0.1555
# Epoch 39/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.1521 - mean_squared_error: 0.1521
# Epoch 40/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1489 - mean_squared_error: 0.1489
# Epoch 41/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.1459 - mean_squared_error: 0.1459
# Epoch 42/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.1429 - mean_squared_error: 0.1429
# Epoch 43/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1401 - mean_squared_error: 0.1401
# Epoch 44/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1374 - mean_squared_error: 0.1374
# Epoch 45/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.1348 - mean_squared_error: 0.1348
# Epoch 46/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1323 - mean_squared_error: 0.1323
# Epoch 47/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1298 - mean_squared_error: 0.1298
# Epoch 48/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1275 - mean_squared_error: 0.1275
# Epoch 49/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1253 - mean_squared_error: 0.1253
# Epoch 50/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1232 - mean_squared_error: 0.1232
# Epoch 51/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1211 - mean_squared_error: 0.1211
# Epoch 52/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1192 - mean_squared_error: 0.1192
# Epoch 53/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1173 - mean_squared_error: 0.1173
# Epoch 54/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1155 - mean_squared_error: 0.1155
# Epoch 55/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.1137 - mean_squared_error: 0.1137
# Epoch 56/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.1120 - mean_squared_error: 0.1120
# Epoch 57/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.1104 - mean_squared_error: 0.1104
# Epoch 58/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.1089 - mean_squared_error: 0.1089
# Epoch 59/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.1074 - mean_squared_error: 0.1074
# Epoch 60/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.1060 - mean_squared_error: 0.1060
# Epoch 61/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.1046 - mean_squared_error: 0.1046
# Epoch 62/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.1033 - mean_squared_error: 0.1033
# Epoch 63/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.1020 - mean_squared_error: 0.1020
# Epoch 64/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.1008 - mean_squared_error: 0.1008
# Epoch 65/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0996 - mean_squared_error: 0.0996
# Epoch 66/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0984 - mean_squared_error: 0.0984
# Epoch 67/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0973 - mean_squared_error: 0.0973
# Epoch 68/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0963 - mean_squared_error: 0.0963
# Epoch 69/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0953 - mean_squared_error: 0.0953
# Epoch 70/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0943 - mean_squared_error: 0.0943
# Epoch 71/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0933 - mean_squared_error: 0.0933
# Epoch 72/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0924 - mean_squared_error: 0.0924
# Epoch 73/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0916 - mean_squared_error: 0.0916
# Epoch 74/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0907 - mean_squared_error: 0.0907
# Epoch 75/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0899 - mean_squared_error: 0.0899
# Epoch 76/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0891 - mean_squared_error: 0.0891
# Epoch 77/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0883 - mean_squared_error: 0.0883
# Epoch 78/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0876 - mean_squared_error: 0.0876
# Epoch 79/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0869 - mean_squared_error: 0.0869
# Epoch 80/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0862 - mean_squared_error: 0.0862
# Epoch 81/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0856 - mean_squared_error: 0.0856
# Epoch 82/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0849 - mean_squared_error: 0.0849
# Epoch 83/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0843 - mean_squared_error: 0.0843
# Epoch 84/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0837 - mean_squared_error: 0.0837
# Epoch 85/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0831 - mean_squared_error: 0.0831
# Epoch 86/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0826 - mean_squared_error: 0.0826
# Epoch 87/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0821 - mean_squared_error: 0.0821
# Epoch 88/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0815 - mean_squared_error: 0.0815
# Epoch 89/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0810 - mean_squared_error: 0.0810
# Epoch 90/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0805 - mean_squared_error: 0.0805
# Epoch 91/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0801 - mean_squared_error: 0.0801
# Epoch 92/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0796 - mean_squared_error: 0.0796
# Epoch 93/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0792 - mean_squared_error: 0.0792
# Epoch 94/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0787 - mean_squared_error: 0.0787
# Epoch 95/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0783 - mean_squared_error: 0.0783
# Epoch 96/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0779 - mean_squared_error: 0.0779
# Epoch 97/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0775 - mean_squared_error: 0.0775
# Epoch 98/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0771 - mean_squared_error: 0.0771
# Epoch 99/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0768 - mean_squared_error: 0.0768
# Epoch 100/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0764 - mean_squared_error: 0.0764
# Epoch 101/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0761 - mean_squared_error: 0.0761
# Epoch 102/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0757 - mean_squared_error: 0.0757
# Epoch 103/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0754 - mean_squared_error: 0.0754
# Epoch 104/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0751 - mean_squared_error: 0.0751
# Epoch 105/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0747 - mean_squared_error: 0.0747
# Epoch 106/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0744 - mean_squared_error: 0.0744
# Epoch 107/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0741 - mean_squared_error: 0.0741
# Epoch 108/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0738 - mean_squared_error: 0.0738
# Epoch 109/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0736 - mean_squared_error: 0.0736
# Epoch 110/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0733 - mean_squared_error: 0.0733
# Epoch 111/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0730 - mean_squared_error: 0.0730
# Epoch 112/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0727 - mean_squared_error: 0.0727
# Epoch 113/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0725 - mean_squared_error: 0.0725
# Epoch 114/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0722 - mean_squared_error: 0.0722
# Epoch 115/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0720 - mean_squared_error: 0.0720
# Epoch 116/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0717 - mean_squared_error: 0.0717
# Epoch 117/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0715 - mean_squared_error: 0.0715
# Epoch 118/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0713 - mean_squared_error: 0.0713
# Epoch 119/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0710 - mean_squared_error: 0.0710
# Epoch 120/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0708 - mean_squared_error: 0.0708
# Epoch 121/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0706 - mean_squared_error: 0.0706
# Epoch 122/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0704 - mean_squared_error: 0.0704
# Epoch 123/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0702 - mean_squared_error: 0.0702
# Epoch 124/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0700 - mean_squared_error: 0.0700
# Epoch 125/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0698 - mean_squared_error: 0.0698
# Epoch 126/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0696 - mean_squared_error: 0.0696
# Epoch 127/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0694 - mean_squared_error: 0.0694
# Epoch 128/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.0692 - mean_squared_error: 0.0692
# Epoch 129/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0690 - mean_squared_error: 0.0690
# Epoch 130/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0688 - mean_squared_error: 0.0688
# Epoch 131/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0686 - mean_squared_error: 0.0686
# Epoch 132/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0685 - mean_squared_error: 0.0685
# Epoch 133/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0683 - mean_squared_error: 0.0683
# Epoch 134/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0681 - mean_squared_error: 0.0681
# Epoch 135/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0679 - mean_squared_error: 0.0679
# Epoch 136/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0678 - mean_squared_error: 0.0678
# Epoch 137/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0676 - mean_squared_error: 0.0676
# Epoch 138/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0674 - mean_squared_error: 0.0674
# Epoch 139/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0673 - mean_squared_error: 0.0673
# Epoch 140/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0671 - mean_squared_error: 0.0671
# Epoch 141/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0669 - mean_squared_error: 0.0669
# Epoch 142/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0668 - mean_squared_error: 0.0668
# Epoch 143/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0666 - mean_squared_error: 0.0666
# Epoch 144/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0665 - mean_squared_error: 0.0665
# Epoch 145/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0663 - mean_squared_error: 0.0663
# Epoch 146/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0662 - mean_squared_error: 0.0662
# Epoch 147/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0660 - mean_squared_error: 0.0660
# Epoch 148/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0659 - mean_squared_error: 0.0659
# Epoch 149/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0657 - mean_squared_error: 0.0657
# Epoch 150/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0656 - mean_squared_error: 0.0656
# Epoch 151/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0654 - mean_squared_error: 0.0654
# Epoch 152/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0653 - mean_squared_error: 0.0653
# Epoch 153/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0652 - mean_squared_error: 0.0652
# Epoch 154/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0650 - mean_squared_error: 0.0650
# Epoch 155/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0649 - mean_squared_error: 0.0649
# Epoch 156/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0647 - mean_squared_error: 0.0647
# Epoch 157/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0646 - mean_squared_error: 0.0646
# Epoch 158/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0645 - mean_squared_error: 0.0645
# Epoch 159/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0643 - mean_squared_error: 0.0643
# Epoch 160/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0642 - mean_squared_error: 0.0642
# Epoch 161/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0641 - mean_squared_error: 0.0641
# Epoch 162/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0639 - mean_squared_error: 0.0639
# Epoch 163/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0638 - mean_squared_error: 0.0638
# Epoch 164/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0637 - mean_squared_error: 0.0637
# Epoch 165/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0636 - mean_squared_error: 0.0636
# Epoch 166/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0634 - mean_squared_error: 0.0634
# Epoch 167/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0633 - mean_squared_error: 0.0633
# Epoch 168/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0632 - mean_squared_error: 0.0632
# Epoch 169/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0631 - mean_squared_error: 0.0631
# Epoch 170/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0629 - mean_squared_error: 0.0629
# Epoch 171/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0628 - mean_squared_error: 0.0628
# Epoch 172/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.0627 - mean_squared_error: 0.0627
# Epoch 173/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.0626 - mean_squared_error: 0.0626
# Epoch 174/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0624 - mean_squared_error: 0.0624
# Epoch 175/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0623 - mean_squared_error: 0.0623
# Epoch 176/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0622 - mean_squared_error: 0.0622
# Epoch 177/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0621 - mean_squared_error: 0.0621
# Epoch 178/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0620 - mean_squared_error: 0.0620
# Epoch 179/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0618 - mean_squared_error: 0.0618
# Epoch 180/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0617 - mean_squared_error: 0.0617
# Epoch 181/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0616 - mean_squared_error: 0.0616
# Epoch 182/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0615 - mean_squared_error: 0.0615
# Epoch 183/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0614 - mean_squared_error: 0.0614
# Epoch 184/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0613 - mean_squared_error: 0.0613
# Epoch 185/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0611 - mean_squared_error: 0.0611
# Epoch 186/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0610 - mean_squared_error: 0.0610
# Epoch 187/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0609 - mean_squared_error: 0.0609
# Epoch 188/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0608 - mean_squared_error: 0.0608
# Epoch 189/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0607 - mean_squared_error: 0.0607
# Epoch 190/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0606 - mean_squared_error: 0.0606
# Epoch 191/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0605 - mean_squared_error: 0.0605
# Epoch 192/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0603 - mean_squared_error: 0.0603
# Epoch 193/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0602 - mean_squared_error: 0.0602
# Epoch 194/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0601 - mean_squared_error: 0.0601
# Epoch 195/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0600 - mean_squared_error: 0.0600
# Epoch 196/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0599 - mean_squared_error: 0.0599
# Epoch 197/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0598 - mean_squared_error: 0.0598
# Epoch 198/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0597 - mean_squared_error: 0.0597
# Epoch 199/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0596 - mean_squared_error: 0.0596
# Epoch 200/200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0594 - mean_squared_error: 0.0594
# Adaline - MSE: 0.0593

# %% [markdown]
# ## Implementación con `Pytorch`

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Declaramos los datos como tensores, tanto en la matriz de características
X = torch.tensor([
    [5, 1.5, 1],
    [3, 2.0, 0],
    [4, 1.0, 1],
    [2, 2.5, 0],
    [6, 1.2, 1],
    [3.5, 2.2, 0]
], dtype=torch.float32)


# como la de la característica objetivo
y = torch.tensor([[1], [0], [1], [0], [1], [0]], dtype=torch.float32)

# %%
# Hacemos algo muy similar al caso del Perceptrón. Creamos la clase Adaline que
# hereda de nn.Module.

class Adaline(nn.Module):
    def __init__(self):
        super(Adaline, self).__init__()
        self.linear = nn.Linear(3, 1) #tenemos 3 entradas y solo una neurona operando

    def forward(self, x):
        return self.linear(x) #tenemos la función de activación lineal a la salida

model_adaline_pytorch = Adaline() #creamos el objeto model_adaline_pytorch de la clase Adaline

# Definimos la función de pérdida con el MSE y el optimizador de gradiente descendente estocástico
criterion_adaline = nn.MSELoss()
optimizer_adaline = optim.SGD(model_adaline_pytorch.parameters(), lr=0.01) #como hiperpámetro está la tasa de aprendizaje

# Entrenamos el modelo como en el caso del perceptrón
for epoch in range(100):
    optimizer_adaline.zero_grad()
    outputs = model_adaline_pytorch(X)
    loss = criterion_adaline(outputs, y)
    loss.backward()
    optimizer_adaline.step()

# Evaluamos el modelo con el error de entrenamiento y el MSE
with torch.no_grad():
    mse = criterion_adaline(model_adaline_pytorch(X), y)
    print(f'Adaline (PyTorch) - MSE: {mse.item():.4f}')
# Out:
# Adaline (PyTorch) - MSE: 0.0152
